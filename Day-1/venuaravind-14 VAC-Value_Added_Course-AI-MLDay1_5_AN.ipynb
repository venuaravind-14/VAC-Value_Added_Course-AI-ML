# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/venuaravind-14%20VAC-Value_Added_Course-AI-MLDay1_5_AN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install spacy

# %%
# !python -m spacy download en
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 95.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(u'Telsa is looking at buying U.S. startup for $6million')
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Telsa NOUN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup NOUN dobj
# for ADP prep
# $ SYM nmod
# 6million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7a8f19888cb0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7a8f198898b0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7a8f197ee8f0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7a8f1962acd0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7a8f19638fd0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7a8f197ee880>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2=nlp(u"Telsa isn't looking into startup anymore")

# %%
for token in doc2:
    print(token.text, token.pos_, token.dep_)
# Out:
# Telsa NOUN nsubj
# is AUX aux
# n't PART neg
# looking VERB ROOT
# into ADP prep
# startup NOUN pobj
# anymore ADV advmod

# %%
doc2
# Out:
# Telsa isn't looking into startup anymore

# %%
doc[0]
# Out:
# Telsa

# %%
type(doc2)
# Out:
# spacy.tokens.doc.Doc

# %%
doc[0].pos_
# Out:
# 'NOUN'

# %%
doc[0].dep_
# Out:
# 'nsubj'

# %%
spacy.explain('nsubj')
# Out:
# 'nominal subject'

# %%
print(doc2[4].pos_)
# Out:
# ADP

# %%
print(doc2[4].tag_+'/'+ spacy.explain(doc2[4].tag_))
# Out:
# IN/conjunction, subordinating or preposition

# %%
print(doc[0].is_alpha)
# Out:
# True

# %%
print(doc[0].is_stop)
# Out:
# False

# %%
doc3=nlp(u"""Although commonly attributed to John Lennon from his song "beautiful boy",\ the phrase "Life is what happens to us while we are making other plans" was written by cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when lennon was 17.""")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-3298368729.py:1: SyntaxWarning: invalid escape sequence '\ '
#   doc3=nlp(u"""Although commonly attributed to John Lennon from his song "beautiful boy",\ the phrase "Life is what happens to us while we are making other plans" was written by cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when lennon was 17.""")

# %%
life_qoute = doc3[16:30]

# %%
print(life_qoute)
# Out:
# is what happens to us while we are making other plans" was written

# %%
type(life_qoute)
# Out:
# spacy.tokens.span.Span

# %%
doc4 = nlp(u'This is the first sentence. This is another sentence. This is the last sentence')

# %%
for sent in doc4.sents:
  print(sent)
# Out:
# This is the first sentence.
# This is another sentence.
# This is the last sentence

# %%
doc4[6].is_sent_start
# Out:
# True
