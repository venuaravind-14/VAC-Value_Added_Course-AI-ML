# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/Day2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u'This is the first sentence. This is another sentence. This is the last sentence')
for sent in doc.sents:
    print(sent)
# Out:
# This is the first sentence.
# This is another sentence.
# This is the last sentence

# %%
print(doc[1])
# Out:
# is

# %%
sentences = list(doc.sents)
print(sentences[1])
# Out:
# This is another sentence.

# %%
doc_sents = [sent for sent in doc.sents]
doc_sents
# Out:
# [This is the first sentence.,
#  This is another sentence.,
#  This is the last sentence]

# %%
print(doc_sents[1])
# Out:
# This is another sentence.

# %%
type(doc_sents[1])
# Out:
# spacy.tokens.span.Span

# %%
print(doc_sents[1].start, doc_sents[1].end)
# Out:
# 6 11

# %%
doc2 = nlp(u'This is a sentence. This is a sentence. This is a sentence.')
for token in doc2:
    print(token.is_sent_start, ' '+token.text)
# Out:
# True  This
# False  is
# False  a
# False  sentence
# False  .
# True  This
# False  is
# False  a
# False  sentence
# False  .
# True  This
# False  is
# False  a
# False  sentence
# False  .

# %%
doc = nlp(u'"Management is doing the things right; leadership is doing the right things." -Peter Drucker')
for sent in doc.sents:
    print(sent)
    print('\n')
# Out:
# "Management is doing the things right; leadership is doing the right things."
#
#
# -Peter Drucker

# %%
doc
# Out:
# "Management is doing the things right; leadership is doing the right things." -Peter Drucker

# %%
doc[:-1]
# Out:
# "Management is doing the things right; leadership is doing the right things." -Peter

# %%
from spacy.language import Language
@Language.component("set_custom_boundaries")

def set_custom_boundaries(doc):
  for token in doc[:-1]:
    if token.text == ';':
      doc[token.i+1].is_sent_start = True
  return doc

# %%
nlp.add_pipe("set_custom_boundaries", after='parser')

print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'set_custom_boundaries', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc4 = nlp('"Management is doing things right; leadership is doing the right things." -Peter Drucker')

for sent in doc4.sents:
    print(sent)
# Out:
# "Management is doing things right; leadership is doing the right things."
# -Peter Drucker

# %%
nlp.add_pipe("set_custom_boundaries", before='parser')

print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'set_custom_boundaries', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc4[4]
# Out:
# things

# %%
import spacy
from spacy.pipeline import Sentencizer
nlp = spacy.load("en_core_web_sm")
nlp.remove_pipe("parser")
nlp.add_pipe("sentencizer")

doc4 = nlp('"Management is doing the things right; leadership is doing the right things." -Peter Drucker')

for sent in doc4.sents:
    print(sent.text)

doc4[4].is_sent_start = True
# Out:
# "Management is doing the things right; leadership is doing the right things."
# -Peter Drucker

# %%
nlp = spacy.load("en_core_web_sm")

mystring = u'This is a sentence. This is another.\n\nThis is a \nthird sentence.'

doc = nlp(mystring)

for sent in doc.sents:
  print([token.text for token in sent])
# Out:
# ['This', 'is', 'a', 'sentence', '.']
# ['This', 'is', 'another', '.', '\n\n']
# ['This', 'is', 'a', '\n', 'third', 'sentence', '.']

# %% [markdown]
# SENTENCE SEGMENTATION
