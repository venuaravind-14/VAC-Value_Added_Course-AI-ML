# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/Day1.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name='Venu Aravind'
print('His name is {var}.'.format(var=name))
# Out:
# His name is Venu Aravind.

# %%
name='Venu Aravind'
course='AI&ML'
message=f'My name is {name} and I am learning {course}'
print(message)
# Out:
# My name is Venu Aravind and I am learning AI&ML

# %%
name='Venu Aravind'
print(f'His name is {name!r}.')
# Out:
# His name is 'Venu Aravind'.

# %%
d= {'a':123,'b':456}
print(f"Address: {d['a']} Main Street")
# Out:
# Address: 123 Main Street

# %%
library = [('Author','Topic','Pages'),('Twain','Rafting',601),('Feynman','Physics',95),('Hamilton','Mythology',144)]
for book in library:
    print(f'{book[0]:{10}}{book[1]:{8}}{book[2]:{7}}')
# Out:
# Author    Topic   Pages
# Twain     Rafting     601
# Feynman   Physics      95
# Hamilton  Mythology    144

# %%
for book in library:
  print(f'{book[0]:{10}}{book[1]:{10}}{book[2]:.>{7}}')
# Out:
# Author    Topic     ..Pages
# Twain     Rafting   ....601
# Feynman   Physics   .....95
# Hamilton  Mythology ....144

# %%
from datetime import datetime
today= datetime(year=2018,month=1,day=27)
print(f'{today:%B %d, %Y}')
# Out:
# January 27, 2018

# %%
# %%writefile LOYOLA.txt
# Hello, This is a quick text file.
# This is the second line of the file.
# Out:
# Writing LOYOLA.txt

# %%
my_file=open('LOYOLA.txt')
my_file.read()
# Out:
# 'Hello, This is a quick text file.\nThis is the second line of the file.\n'

# %%
pwd
# Out:
# '/content'

# %%
my_file.read()
# Out:
# ''

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.readlines()
# Out:
# ['Hello, This is a quick text file.\n',
#  'This is the second line of the file.\n']

# %%
my_file.seek(0)
my_file.readlines()
# Out:
# ['Hello, This is a quick text file.\n',
#  'This is the second line of the file.\n']

# %%
my_file.close()

# %%
my_file=open('LOYOLA.txt','w+')
my_file.write('This a new first line')
# Out:
# 21

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'This a new first line'

# %%
my_file.close()
my_file=open('LOYOLA.txt','a+')
my_file.write('\nThis line is appended at the end of the previous contents in the file.')
# Out:
# 71

# %%
my_file.seek(0)
print(my_file.read())
# Out:
# This a new first line
# This line is appended at the end of the previous contents in the file.

# %%
with open('LOYOLA.txt','r') as txt:
    first_line=txt.readlines()[0]
print(first_line)
# Out:
# This a new first line

# %%
with open('LOYOLA.txt','r') as txt:
    for line in txt:
        print(line,end='')
# Out:
# This a new first line
# This line is appended at the end of the previous contents in the file.
