# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/Day1_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem.porter import *
p_stemmer = PorterStemmer()
words = 'consolingly'

# %%
print('Porter Stemmer:')
for word in words:
    print(word+' --> '+p_stemmer.stem(word))
# Out:
# Porter Stemmer:
# c --> c
# o --> o
# n --> n
# s --> s
# o --> o
# l --> l
# i --> i
# n --> n
# g --> g
# l --> l
# y --> y

# %%
from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')

# %%
print('Porter2 Stemmer')
for word in words:
  print(word+' --> '+s_stemmer.stem(word))
# Out:
# Porter2 Stemmer
# c --> c
# o --> o
# n --> n
# s --> s
# o --> o
# l --> l
# i --> i
# n --> n
# g --> g
# l --> l
# y --> y

# %%
phrase = 'I am meeting him tomorrow at the meeting'
for word in phrase.split():
  print(word+' --> '+s_stemmer.stem(word))
# Out:
# I --> i
# am --> am
# meeting --> meet
# him --> him
# tomorrow --> tomorrow
# at --> at
# the --> the
# meeting --> meet

# %%
phrase = 'A sentence is a grammatically complete, meaningful unit of words containing a subject and a verb, starting with a capital letter and ending with a period, question mark, or exclamation mark.'
for word in phrase.split():
  print(word+' --> '+p_stemmer.stem(word))
# Out:
# A --> a
# sentence --> sentenc
# is --> is
# a --> a
# grammatically --> grammat
# complete, --> complete,
# meaningful --> meaning
# unit --> unit
# of --> of
# words --> word
# containing --> contain
# a --> a
# subject --> subject
# and --> and
# a --> a
# verb, --> verb,
# starting --> start
# with --> with
# a --> a
# capital --> capit
# letter --> letter
# and --> and
# ending --> end
# with --> with
# a --> a
# period, --> period,
# question --> question
# mark, --> mark,
# or --> or
# exclamation --> exclam
# mark. --> mark.

# %%
phrase = 'I am attending Certificate Course on Advanced AI'
for word in phrase.split():
  print(word+' --> '+s_stemmer.stem(word))
# Out:
# I --> i
# am --> am
# attending --> attend
# Certificate --> certif
# Course --> cours
# on --> on
# Advanced --> advanc
# AI --> ai
