# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/Day1_6_AN_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
from nltk.stem.porter import *

# %%
p_stemmer = PorterStemmer()

# %%
words = ['run','runner','running','ran','runs','easily','fairly']

# %%
for word in words:
    print(word + '---->' + p_stemmer.stem(word))
# Out:
# run---->run
# runner---->runner
# running---->run
# ran---->ran
# runs---->run
# easily---->easili
# fairly---->fairli

# %%
from nltk.stem.snowball import SnowballStemmer
