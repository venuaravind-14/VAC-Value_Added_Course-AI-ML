# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/Day2_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u"The Quick brown fox jumper over the lazy dog's back.")
print(doc.text)
# Out:
# The Quick brown fox jumper over the lazy dog's back.

# %%
print(doc[4].text, doc[4].pos_, doc[4].tag_, spacy.explain(doc[4].tag_))
# Out:
# jumper NOUN NN noun, singular or mass

# %%
for token in doc:
  print(f"{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}")
# Out:
# The        DET      DT     determiner
# Quick      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# brown      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# fox        NOUN     NN     noun, singular or mass
# jumper     NOUN     NN     noun, singular or mass
# over       ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# lazy       ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# dog        NOUN     NN     noun, singular or mass
# 's         PART     POS    possessive ending
# back       NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer

# %%
doc = nlp(u"I read books on NLP.")
r = doc[1]
print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# read       VERB     VBP    verb, non-3rd person singular present

# %%
doc = nlp(u"I read a book on NLP.")
r = doc[1]
print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# read       VERB     VBD    verb, past tense

# %%
Dep_Counts = doc.count_by(spacy.attrs.DEP)
for k,v in sorted(Dep_Counts.items()):
  print(f"{k}. {doc.vocab[k].text:{5}}: {v}")
# Out:
# 415. det  : 1
# 416. dobj : 1
# 429. nsubj: 1
# 439. pobj : 1
# 443. prep : 1
# 445. punct: 1
# 8206900633647566924. ROOT : 1

# %%
 from spacy import displacy

# %%
doc =nlp(u"The quick brown fox jumped over the lazy dog's back.")

for token in doc:
  print(f"{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.dep_)}")
# Out:
# The        DET      DT     determiner
# quick      ADJ      JJ     adjectival modifier
# brown      ADJ      JJ     adjectival modifier
# fox        NOUN     NN     nominal subject
# jumped     VERB     VBD    root
# over       ADP      IN     prepositional modifier
# the        DET      DT     determiner
# lazy       ADJ      JJ     adjectival modifier
# dog        NOUN     NN     possession modifier
# 's         PART     POS    case marking
# back       NOUN     NN     object of preposition
# .          PUNCT    .      punctuation

# %%
displacy.render(doc,style ='dep', jupyter = True, options = {'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a819cc46068a4f8fa52c6bdf5b464c2f-0" class="displacy" width="1260" height="302.0" direction="ltr" style="max-width: none; height: 302.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
# ...

# %%
doc2 = nlp(u"This is a sentence. This is another possibly longer sentence.")

# %%
spans = list(doc2.sents)

options = {'distance':110, 'compact':'False', 'color':'red', 'bg':'#09a3d', 'font':'Times'}

displacy.render(doc2, style = 'dep', jupyter = True, options = options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ac961e6ef17344a9aa4704419fff2e6c-0" class="displacy" width="1150" height="302.0" direction="ltr" style="max-width: none; height: 302.0px; color: red; background: #09a3d; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">a</tspan>
# ...

# %%
def show_ents(doc):
  if doc.ents:
    for ent in doc.ents:
      print(ent.text +'-'+ ent.label_ +'-'+ str(spacy.explain(ent.label_)))
  else:
    print('No entities found.')

# %%
doc = nlp(U"May I go to Washington, DC next May to see the Washington Monument?")
show_ents(doc)
# Out:
# Washington, DC-GPE-Countries, cities, states
# next May-DATE-Absolute or relative dates or periods
# the Washington Monument-ORG-Companies, agencies, institutions, etc.

# %%
doc = nlp(u'Can I please borrow 500 dollars from you to buy some microsoft stock')
for ent in doc.ents:
  print(ent.text, ent.start, ent.end, ent.start_char, ent.end_char, ent.label_)
# Out:
# 500 dollars 4 6 20 31 MONEY

# %%
doc = nlp(u'Tesla to build a U.K. factory for $6 million')
show_ents(doc)
# Out:
# U.K.-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
doc = nlp(u'Tesla to build a U.K. factory for $6 million')

ORG = doc.vocab.strings[u'ORG']
new_ent = spacy.tokens.span.Span(doc, 0,1,label=ORG)
doc.ents = list(doc.ents) + [new_ent]

show_ents(doc)
# Out:
# Tesla-ORG-Companies, agencies, institutions, etc.
# U.K.-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
doc = nlp(U"Our Company plans to introduce a new vacuum cleaner."U"If Successful, the vacuum cleaner will be our first product.")
show_ents(doc)
# Out:
# Successful-PERSON-People, including fictional
# first-ORDINAL-"first", "second", etc.

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab)

# %%
doc = nlp(U"Our Company plans to introduce a new vacuum cleaner."U"If Successful, the vacuum cleaner will be our first product.")

Phrase_list=['vaccum cleaner','vaccum cleaner']
Phrase_patterns=[nlp(text) for text in Phrase_list]
matcher.add('newProduct',None,*Phrase_patterns)
matches=matcher(doc)
matches
# Out:
# []
