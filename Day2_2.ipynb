# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/Day2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'more', '’s', 'up', 'only', 'to', 'eight', 'nowhere', 'over', 'something', "n't", 'there', 'into', 'is', 'ever', 'did', 'beforehand', 'by', 'me', 'whatever', 'with', 'always', 'never', 'call', 'some', 'often', 'get', 'keep', 'below', 'made', 'becomes', '’re', 'can', 'neither', 'itself', '’ll', 'fifty', 'now', 'if', 'because', 'for', 'onto', 'ca', 'behind', "'ve", 'anywhere', 'noone', 'done', 'twenty', '‘ve', 'former', '‘d', 'once', 'per', 'through', 'these', 'why', 'you', 'just', 'who', 'doing', 'my', 'again', 'two', 'go', '‘s', 'give', 'anything', '’ve', 'on', 'much', 'before', 'but', 'amongst', 'along', 'mine', 'yet', 'the', 'ours', 'during', 'had', 'or', 'may', 'many', 'seeming', '‘re', 'does', 'between', 'it', 'each', 'have', 'otherwise', 'moreover', 'side', 'whose', 'bottom', 'forty', 'nevertheless', 'are', 'see', 'after', 'via', 'as', 'enough', 'whole', 'was', 'himself', 'among', 'his', 'thereafter', "'ll", 'yourself', 'fifteen', 'one', 'even', 'your', 'ten', 'empty', 'already
# ...

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('mystery')

# %% [markdown]
# To add a stop word ||
# Add the word to the set of stop words. Use lowercase!

# %%
nlp.vocab['mystery'].is_stop = True

# %% [markdown]
# Set the stop_word tag on the lexeme

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['mystery'].is_stop
# Out:
# True
