# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/Day_1.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "The agent's phone number is 408-555-1234. Call sooon!"
'phone' in text
# Out:
# True

# %%
import re   # For Searching

# %%
pattern = 'phone'

# %%
match = re.search(pattern,text)

# %%
match
# Out:
# <re.Match object; span=(12, 17), match='phone'>

# %%
match.span()
# Out:
# (12, 17)

# %%
text = "my phone is a new phone"

# %%
match = re.search("phone",text)

# %%
match.span()
# Out:
# (3, 8)

# %%
matches = re.findall("phone",text)

# %%
matches
# Out:
# ['phone', 'phone']

# %%
len(matches)
# Out:
# 2

# %%
for match in re.finditer("phone",text):
    print(match.span())
# Out:
# (3, 8)
# (18, 23)

# %%
text = "My telephone numbeeer is 409-555-1234"
phone = re.search(r'\d\d\d-\d\d\d-\d\d\d\d',text)
phone.group()
# Out:
# '409-555-1234'

# %%
re.search(r'\d{3}-\d{3}-\d{4}',text)
# Out:
# <re.Match object; span=(25, 37), match='409-555-1234'>

# %%
phone_pattern = re.compile(r'(\d{3})-(\d{3})-(\d{4})')

# %%
results = re.search(phone_pattern,text)

# %%
results.group()
# Out:
# '409-555-1234'

# %%
# remember
# group ordering starts at 1.
results.group(1)
# Out:
# '409'

# %%
re.search(r"man|woman","This man was here.")
# Out:
# <re.Match object; span=(5, 8), match='man'>

# %%
re.search(r"man|woman","This woman was here.")
# Out:
# <re.Match object; span=(5, 10), match='woman'>

# %%
re.findall(r"...at","The bat went splat.")
# Out:
# ['e bat', 'splat']

# %%
re.findall(r"\S+at","The bat went splat.")
# Out:
# ['bat', 'splat']

# %%
re.findall(r'\d$','This ends with a number 2')
# Out:
# ['2']

# %%
re.findall(r'^\d','1 is the loneliest number')
# Out:
# ['1']

# %%
phrase = "there are 3 numbers 34 inside 5 this sentence."

# %%
re.findall(r'[^\d]+',phrase) # Removing the Numbers
# Out:
# ['there are ', ' numbers ', ' inside ', ' this sentence.']

# %%
test_phrase = 'This is a string! But it has punctuation. How can we remove it?'

# %%
re.findall('[^!.?]+',test_phrase)
# Out:
# ['This is a string', ' But it has punctuation', ' How can we remove it']

# %%
re.findall('[^!.? ]+',test_phrase)
# Out:
# ['This',
#  'is',
#  'a',
#  'string',
#  'But',
#  'it',
#  'has',
#  'punctuation',
#  'How',
#  'can',
#  'we',
#  'remove',
#  'it']

# %%
clean = ' '.join(re.findall('[^!.? ]+',test_phrase))

# %%
clean
# Out:
# 'This is a string But it has punctuation How can we remove it'

# %%
text = 'Only find the hypen-words in this sentence. But you do not know how long-ish they are'

# %%
re.findall(r'[\w]+-[\w]+',text)
# Out:
# ['hypen-words', 'long-ish']

# %%
text = "Hello, would you like some catfish?"
texttwo = "Hello, would you like to take a catnap?"
textthree = "Hello, have you seen this caterpillar?"

# %%
re.search(r'cat(fish|nap|claw)',text)
# Out:
# <re.Match object; span=(27, 34), match='catfish'>

# %%
re.search(r'cat(fish|nap|claw)',texttwo)
# Out:
# <re.Match object; span=(32, 38), match='catnap'>

# %%
re.search(r'cat(fish|nap|claw)',textthree)
