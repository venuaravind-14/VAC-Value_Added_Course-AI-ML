# %% [markdown]
# <a href="https://colab.research.google.com/github/venuaravind-14/VAC-Value_Added_Course-AI-ML/blob/main/Day1.4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
conda install -c conda-forge spacy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install -c conda-forge spacy')
#
# File C:\Python313\Lib\site-packages\IPython\core\interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File C:\Python313\Lib\site-packages\IPython\core\magics\packaging.py:27, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
# ...

# %%
pip install -U spacy
# Out:
# ...
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.2 MB 4.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.1/14.2 MB 5.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.9/14.2 MB 4.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.2/14.2 MB 5.0 MB/s eta 0:00:03
#    -------------- ------------------------- 5.2/14.2 MB 5.0 MB/s eta 0:00:02
#    ------------------- -------------------- 7.1/14.2 MB 5.5 MB/s eta 0:00:02
#    ------------------------- -------------- 8.9/14.2 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.2/14.2 MB 6.0 MB/s eta 0:00:01
#    -------------------------------- ------- 11.5/14.2 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 12.8/14.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.2 MB 6.2 MB/s eta 0:00:01
# ...

# %%
# %pip install -U spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en-core_web_sm
# Out:
# [x] No compatible package found for 'en-core_web_sm' (spaCy
# v3.8.11)

# %% [raw]
# import spacy

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(u'Telsa is looking at buying U.S. startup for $6million')
for token in doc:
    print(token.text, token.pos_, token.dep_)
